# %% [markdown]
# # Preparación de los datos

# %%
import pandas as pd
import numpy as np
import re

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%writefile /tmp/data.csv
# factura_id,valor,porcentaje
# 1,200$,11.3%
# 2,220$,3.5%
# 3,128$,4.5%
# 4,300$,11.6%
# 5,202$,5.1%
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')

display(
    df,
    df.dtypes
)
# Out:
#    factura_id valor porcentaje
# 0           1  200$      11.3%
# 1           2  220$       3.5%
# 2           3  128$       4.5%
# 3           4  300$      11.6%
# 4           5  202$       5.1%
# factura_id     int64
# valor         object
# porcentaje    object
# dtype: object

# %%
df.describe()
# Out:
#        factura_id
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %%
df.valor = df.valor.str.strip('$')
df.valor = df.valor.astype(int)

# %%
df.describe()
# Out:
#        factura_id      valor
# count    5.000000    5.00000
# mean     3.000000  210.00000
# std      1.581139   61.41661
# min      1.000000  128.00000
# 25%      2.000000  200.00000
# 50%      3.000000  202.00000
# 75%      4.000000  220.00000
# max      5.000000  300.00000

# %%
df.porcentaje = df.porcentaje.str.strip('%')
df.porcentaje = df.porcentaje.astype(float)

# %%
df.describe()
# Out:
#        factura_id      valor  porcentaje
# count    5.000000    5.00000    5.000000
# mean     3.000000  210.00000    7.200000
# std      1.581139   61.41661    3.923009
# min      1.000000  128.00000    3.500000
# 25%      2.000000  200.00000    4.500000
# 50%      3.000000  202.00000    5.100000
# 75%      4.000000  220.00000   11.300000
# max      5.000000  300.00000   11.600000

# %%
display(df.dtypes)
# Out:
# factura_id      int64
# valor           int64
# porcentaje    float64
# dtype: object

# %%
# %%writefile /tmp/data.csv
# id,status
# 1,0
# 2,0
# 3,1
# 3,2
# 4,2
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')

display(
    df,
    df.dtypes
)
# Out:
#    id  status
# 0   1       0
# 1   2       0
# 2   3       1
# 3   3       2
# 4   4       2
# id        int64
# status    int64
# dtype: object

# %%
df.status = df.status.astype('category')

display(
    df,
    df.dtypes
)
# Out:
#    id status
# 0   1      0
# 1   2      0
# 2   3      1
# 3   3      2
# 4   4      2
# id           int64
# status    category
# dtype: object

# %%
df.describe()
# Out:
#              id
# count  5.000000
# mean   2.600000
# std    1.140175
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    3.000000
# max    4.000000

# %%
df.status
# Out:
# 0    0
# 1    0
# 2    1
# 3    2
# 4    2
# Name: status, dtype: category
# Categories (3, int64): [0, 1, 2]

# %%
# %%writefile /tmp/data.csv
# id,rango
# 1,1
# 2,3
# 3,2
# 4,10
# 5,0
# 6,1
# 7,10
# 8,9
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')

# %%
df[(df.rango < 1)|(df.rango > 3)].rango
# Out:
# 3    10
# 4     0
# 6    10
# 7     9
# Name: rango, dtype: int64

# %%
df.rango[df.rango > 3] = 3
df.rango[df.rango < 1] = 1
df
# Out:
#    id  rango
# 0   1      1
# 1   2      3
# 2   3      2
# 3   4      3
# 4   5      1
# 5   6      1
# 6   7      3
# 7   8      3

# %%
df = pd.read_csv('/tmp/data.csv')
df
# Out:
#    id  rango
# 0   1      1
# 1   2      3
# 2   3      2
# 3   4     10
# 4   5      0
# 5   6      1
# 6   7     10
# 7   8      9

# %%
df = df[(df.rango >= 1) & (df.rango <= 3)]
df
# Out:
#    id  rango
# 0   1      1
# 1   2      3
# 2   3      2
# 5   6      1

# %%
df = pd.read_csv('/tmp/data.csv')
df
# Out:
#    id  rango
# 0   1      1
# 1   2      3
# 2   3      2
# 3   4     10
# 4   5      0
# 5   6      1
# 6   7     10
# 7   8      9

# %%
df.drop(
    df[(df.rango < 1) | (df.rango > 3)].index,
    inplace=True
)
df
# Out:
#    id  rango
# 0   1      1
# 1   2      3
# 2   3      2
# 5   6      1

# %%
# %%writefile /tmp/data.csv
# id,fecha
# 1,10/01/2012
# 2,12/04/1890
# 3,10/10/2019
# 4,31/12/2021
# 5,10/12/2035
# 6,05/10/2018
# 7,05/10/2021
# 8,15/12/2020
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')

display(
    df,
    df.dtypes
)
# Out:
#    id       fecha
# 0   1  10/01/2012
# 1   2  12/04/1890
# 2   3  10/10/2019
# 3   4  31/12/2021
# 4   5  10/12/2035
# 5   6  05/10/2018
# 6   7  05/10/2021
# 7   8  15/12/2020
# id        int64
# fecha    object
# dtype: object

# %%
df.fecha = pd.to_datetime(df.fecha)

display(
    df,
    df.dtypes
)
# Out:
#    id      fecha
# 0   1 2012-10-01
# 1   2 1890-12-04
# 2   3 2019-10-10
# 3   4 2021-12-31
# 4   5 2035-10-12
# 5   6 2018-05-10
# 6   7 2021-05-10
# 7   8 2020-12-15
# id                int64
# fecha    datetime64[ns]
# dtype: object

# %%
import datetime as dt
hoy = pd.to_datetime(dt.date.today())
hoy
# Out:
# Timestamp('2021-09-23 00:00:00')

# %%
df[(df.fecha < pd.to_datetime('2000-01-01')) | (df.fecha > hoy)]
# Out:
#    id      fecha
# 1   2 1890-12-04
# 3   4 2021-12-31
# 4   5 2035-10-12

# %%
df.loc[df.fecha < '2000-01-01', 'fecha'] = pd.to_datetime('2000-01-01')
df
# Out:
#    id      fecha
# 0   1 2012-10-01
# 1   2 2000-01-01
# 2   3 2019-10-10
# 3   4 2021-12-31
# 4   5 2035-10-12
# 5   6 2018-05-10
# 6   7 2021-05-10
# 7   8 2020-12-15

# %%
df.loc[df.fecha > hoy, 'fecha'] = hoy
df
# Out:
#    id      fecha
# 0   1 2012-10-01
# 1   2 2000-01-01
# 2   3 2019-10-10
# 3   4 2021-09-23
# 4   5 2021-09-23
# 5   6 2018-05-10
# 6   7 2021-05-10
# 7   8 2020-12-15

# %%
df.dtypes
# Out:
# id                int64
# fecha    datetime64[ns]
# dtype: object

# %%
# %%writefile /tmp/data.csv
# id,nombre,telefono,empresa_id,genero
# 1,Helena,+1 237,1,F
# 2,Juan,+1 345,1,M
# 1,Helena,+1 237,1,F
# 3,Miguel,+1 456,4,M
# 5,Miguel,+1 567,4,M
# 6,Jose,+1 980,2,M
# 7,Ana,+1 123,6,F
# 6,Jose,+1 980,2,M
# 7,Ana,+1 123,6,F
# 1,Helena,+1 237,1,F
# 1,Helena,+1 237,1,F
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')

display(
    df,
    df.dtypes
)
# Out:
#     id  nombre telefono  empresa_id genero
# 0    1  Helena   +1 237           1      F
# 1    2    Juan   +1 345           1      M
# 2    1  Helena   +1 237           1      F
# 3    3  Miguel   +1 456           4      M
# 4    5  Miguel   +1 567           4      M
# 5    6    Jose   +1 980           2      M
# 6    7     Ana   +1 123           6      F
# 7    6    Jose   +1 980           2      M
# 8    7     Ana   +1 123           6      F
# 9    1  Helena   +1 237           1      F
# 10   1  Helena   +1 237           1      F
# id             int64
# nombre        object
# telefono      object
# empresa_id     int64
# genero        object
# dtype: object

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# dtype: bool

# %%
df[df.duplicated(keep='first')]
# Out:
#     id  nombre telefono  empresa_id genero
# 2    1  Helena   +1 237           1      F
# 7    6    Jose   +1 980           2      M
# 8    7     Ana   +1 123           6      F
# 9    1  Helena   +1 237           1      F
# 10   1  Helena   +1 237           1      F

# %%
df[df.duplicated(keep='last')]
# Out:
#    id  nombre telefono  empresa_id genero
# 0   1  Helena   +1 237           1      F
# 2   1  Helena   +1 237           1      F
# 5   6    Jose   +1 980           2      M
# 6   7     Ana   +1 123           6      F
# 9   1  Helena   +1 237           1      F

# %%
df[df.duplicated(
    subset=['nombre','empresa_id'],
    keep=False
)]
# Out:
#     id  nombre telefono  empresa_id genero
# 0    1  Helena   +1 237           1      F
# 2    1  Helena   +1 237           1      F
# 3    3  Miguel   +1 456           4      M
# 4    5  Miguel   +1 567           4      M
# 5    6    Jose   +1 980           2      M
# 6    7     Ana   +1 123           6      F
# 7    6    Jose   +1 980           2      M
# 8    7     Ana   +1 123           6      F
# 9    1  Helena   +1 237           1      F
# 10   1  Helena   +1 237           1      F

# %%
df[df.duplicated()]
# Out:
#     id  nombre telefono  empresa_id genero
# 2    1  Helena   +1 237           1      F
# 7    6    Jose   +1 980           2      M
# 8    7     Ana   +1 123           6      F
# 9    1  Helena   +1 237           1      F
# 10   1  Helena   +1 237           1      F

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#    id  nombre telefono  empresa_id genero
# 0   1  Helena   +1 237           1      F
# 1   2    Juan   +1 345           1      M
# 3   3  Miguel   +1 456           4      M
# 4   5  Miguel   +1 567           4      M
# 5   6    Jose   +1 980           2      M
# 6   7     Ana   +1 123           6      F

# %%
# %%writefile /tmp/data.csv
# id,categoria
# 1,AA
# 2,A
# 3,AB
# 4,Z
# 5,AA
# 6,ZB
# 7,BA
# 8,BB
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')
display(
    df,
    df.dtypes
)
# Out:
#    id categoria
# 0   1        AA
# 1   2         A
# 2   3        AB
# 3   4         Z
# 4   5        AA
# 5   6        ZB
# 6   7        BA
# 7   8        BB
# id            int64
# categoria    object
# dtype: object

# %%
validas = {'AA','AB','BA','BB'}
set(df.categoria).difference(validas)
# Out:
# {'A', 'Z', 'ZB'}

# %%
df[~df.categoria.isin(validas)]
# Out:
#    id categoria
# 1   2         A
# 3   4         Z
# 5   6        ZB

# %%
df = df[df.categoria.isin(validas)]
df
# Out:
#    id categoria
# 0   1        AA
# 2   3        AB
# 4   5        AA
# 6   7        BA
# 7   8        BB

# %%
# %%writefile /tmp/data.csv
# id,estado
# 1,leve
# 2,Leve
# 3,LEVE
# 4,Grave
# 5,GRAVE
# 6,fallecido
# 7,Fallecido
# 8,leve
# 9,leve
# 10,GRAVE
# 11,Grave
# 12,fallecido
# 13,fallecido
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')
df
# Out:
#     id     estado
# 0    1       leve
# 1    2       Leve
# 2    3       LEVE
# 3    4      Grave
# 4    5      GRAVE
# 5    6  fallecido
# 6    7  Fallecido
# 7    8       leve
# 8    9       leve
# 9   10      GRAVE
# 10  11      Grave
# 11  12  fallecido
# 12  13  fallecido

# %%
df.estado.value_counts()
# Out:
# leve         3
# fallecido    3
# GRAVE        2
# Grave        2
# Leve         1
# Fallecido    1
# LEVE         1
# Name: estado, dtype: int64

# %%
estado_df = pd.DataFrame({'estado': list(df.estado)})
estado_df
# Out:
#        estado
# 0        leve
# 1        Leve
# 2        LEVE
# 3       Grave
# 4       GRAVE
# 5   fallecido
# 6   Fallecido
# 7        leve
# 8        leve
# 9       GRAVE
# 10      Grave
# 11  fallecido
# 12  fallecido

# %%
estado_df = estado_df.drop_duplicates()
estado_df
# Out:
#       estado
# 0       leve
# 1       Leve
# 2       LEVE
# 3      Grave
# 4      GRAVE
# 5  fallecido
# 6  Fallecido

# %%
estado_df['key'] = estado_df.estado.str.lower()
estado_df
# Out:
#       estado        key
# 0       leve       leve
# 1       Leve       leve
# 2       LEVE       leve
# 3      Grave      grave
# 4      GRAVE      grave
# 5  fallecido  fallecido
# 6  Fallecido  fallecido

# %%
estado_df.groupby('key').agg(list)
# Out:
#                            estado
# key
# fallecido  [fallecido, Fallecido]
# grave              [Grave, GRAVE]
# leve           [leve, Leve, LEVE]

# %%
df['estado'] = df.estado.str.lower()
df
# Out:
#     id     estado
# 0    1       leve
# 1    2       leve
# 2    3       leve
# 3    4      grave
# 4    5      grave
# 5    6  fallecido
# 6    7  fallecido
# 7    8       leve
# 8    9       leve
# 9   10      grave
# 10  11      grave
# 11  12  fallecido
# 12  13  fallecido

# %%
df.estado.value_counts()
# Out:
# leve         5
# grave        4
# fallecido    4
# Name: estado, dtype: int64

# %%
# %%writefile /tmp/data.csv
# id,estado
# 1,mujer_leve
# 2,mujer Leve
# 3,MUJER_LEVE
# 4,hombre_Grave
# 5,hombre_GRAVE
# 6,hombre fallecido
# 7,hombre_Fallecido
# 8,hombre leve
# 9,mujer leve
# 10,hombre GRAVE
# 11,hombre Grave
# 12,mujer_fallecido
# 13,mujer fallecido
# 14,hombre_fallecido
# 15,hombre Fallecido
# 16,mujer_leve
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')
df
# Out:
#     id            estado
# 0    1        mujer_leve
# 1    2        mujer Leve
# 2    3        MUJER_LEVE
# 3    4      hombre_Grave
# 4    5      hombre_GRAVE
# 5    6  hombre fallecido
# 6    7  hombre_Fallecido
# 7    8       hombre leve
# 8    9        mujer leve
# 9   10      hombre GRAVE
# 10  11      hombre Grave
# 11  12   mujer_fallecido
# 12  13   mujer fallecido
# 13  14  hombre_fallecido
# 14  15  hombre Fallecido
# 15  16        mujer_leve

# %%
df.estado.value_counts()
# Out:
# mujer_leve          2
# hombre leve         1
# hombre fallecido    1
# mujer fallecido     1
# hombre Grave        1
# mujer_fallecido     1
# hombre_Grave        1
# mujer Leve          1
# hombre_Fallecido    1
# hombre_fallecido    1
# mujer leve          1
# MUJER_LEVE          1
# hombre Fallecido    1
# hombre_GRAVE        1
# hombre GRAVE        1
# Name: estado, dtype: int64

# %%
estado_df = pd.DataFrame({ 'estado': list(df.estado)})
estado_df
# Out:
#               estado
# 0         mujer_leve
# 1         mujer Leve
# 2         MUJER_LEVE
# 3       hombre_Grave
# 4       hombre_GRAVE
# 5   hombre fallecido
# 6   hombre_Fallecido
# 7        hombre leve
# 8         mujer leve
# 9       hombre GRAVE
# 10      hombre Grave
# 11   mujer_fallecido
# 12   mujer fallecido
# 13  hombre_fallecido
# 14  hombre Fallecido
# 15        mujer_leve

# %%
estado_df = estado_df.drop_duplicates()
estado_df
# Out:
#               estado
# 0         mujer_leve
# 1         mujer Leve
# 2         MUJER_LEVE
# 3       hombre_Grave
# 4       hombre_GRAVE
# 5   hombre fallecido
# 6   hombre_Fallecido
# 7        hombre leve
# 8         mujer leve
# 9       hombre GRAVE
# 10      hombre Grave
# 11   mujer_fallecido
# 12   mujer fallecido
# 13  hombre_fallecido
# 14  hombre Fallecido

# %%
estado_df['key'] = estado_df.estado.str.lower()
estado_df
# Out:
#               estado               key
# 0         mujer_leve        mujer_leve
# 1         mujer Leve        mujer leve
# 2         MUJER_LEVE        mujer_leve
# 3       hombre_Grave      hombre_grave
# 4       hombre_GRAVE      hombre_grave
# 5   hombre fallecido  hombre fallecido
# 6   hombre_Fallecido  hombre_fallecido
# 7        hombre leve       hombre leve
# 8         mujer leve        mujer leve
# 9       hombre GRAVE      hombre grave
# 10      hombre Grave      hombre grave
# 11   mujer_fallecido   mujer_fallecido
# 12   mujer fallecido   mujer fallecido
# 13  hombre_fallecido  hombre_fallecido
# 14  hombre Fallecido  hombre fallecido

# %%
estado_df.groupby('key').agg(list)
# Out:
#                                                 estado
# key
# hombre fallecido  [hombre fallecido, hombre Fallecido]
# hombre grave              [hombre GRAVE, hombre Grave]
# hombre leve                              [hombre leve]
# hombre_fallecido  [hombre_Fallecido, hombre_fallecido]
# hombre_grave              [hombre_Grave, hombre_GRAVE]
# mujer fallecido                      [mujer fallecido]
# mujer leve                    [mujer Leve, mujer leve]
# mujer_fallecido                      [mujer_fallecido]
# mujer_leve                    [mujer_leve, MUJER_LEVE]

# %%
estado_df['key'] = estado_df.key.str.replace(' ', '_')
estado_df
# Out:
#               estado               key
# 0         mujer_leve        mujer_leve
# 1         mujer Leve        mujer_leve
# 2         MUJER_LEVE        mujer_leve
# 3       hombre_Grave      hombre_grave
# 4       hombre_GRAVE      hombre_grave
# 5   hombre fallecido  hombre_fallecido
# 6   hombre_Fallecido  hombre_fallecido
# 7        hombre leve       hombre_leve
# 8         mujer leve        mujer_leve
# 9       hombre GRAVE      hombre_grave
# 10      hombre Grave      hombre_grave
# 11   mujer_fallecido   mujer_fallecido
# 12   mujer fallecido   mujer_fallecido
# 13  hombre_fallecido  hombre_fallecido
# 14  hombre Fallecido  hombre_fallecido

# %%
estado_df.groupby('key').agg(list)
# Out:
#                                                              estado
# key
# hombre_fallecido  [hombre fallecido, hombre_Fallecido, hombre_fa...
# hombre_grave      [hombre_Grave, hombre_GRAVE, hombre GRAVE, hom...
# hombre_leve                                           [hombre leve]
# mujer_fallecido                  [mujer_fallecido, mujer fallecido]
# mujer_leve         [mujer_leve, mujer Leve, MUJER_LEVE, mujer leve]

# %%
df['estado'] = df.estado.str.replace(' ', '_')
df['estado'] = df.estado.str.lower()
df
# Out:
#     id            estado
# 0    1        mujer_leve
# 1    2        mujer_leve
# 2    3        mujer_leve
# 3    4      hombre_grave
# 4    5      hombre_grave
# 5    6  hombre_fallecido
# 6    7  hombre_fallecido
# 7    8       hombre_leve
# 8    9        mujer_leve
# 9   10      hombre_grave
# 10  11      hombre_grave
# 11  12   mujer_fallecido
# 12  13   mujer_fallecido
# 13  14  hombre_fallecido
# 14  15  hombre_fallecido
# 15  16        mujer_leve

# %%
df.estado.value_counts()
# Out:
# mujer_leve          5
# hombre_grave        4
# hombre_fallecido    4
# mujer_fallecido     2
# hombre_leve         1
# Name: estado, dtype: int64

# %%
# %%writefile /tmp/data.csv
# salario
# 1000
# 500
# 2000
# 800
# 1200
# 100
# 300
# 900
# 550
# 750
# 1500
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')
df
# Out:
#     salario
# 0      1000
# 1       500
# 2      2000
# 3       800
# 4      1200
# 5       100
# 6       300
# 7       900
# 8       550
# 9       750
# 10     1500

# %%
rangos = [0, 499, 999, 1499, np.inf]
nombres = ['0-499', '500-999', '1000-1499', '1500+']

df['categoria'] = pd.cut(
    df.salario,
    bins=rangos,
    labels=nombres
)
df
# Out:
#     salario  categoria
# 0      1000  1000-1499
# 1       500    500-999
# 2      2000      1500+
# 3       800    500-999
# 4      1200  1000-1499
# 5       100      0-499
# 6       300      0-499
# 7       900    500-999
# 8       550    500-999
# 9       750    500-999
# 10     1500      1500+

# %%
df.categoria.value_counts()
# Out:
# 500-999      5
# 0-499        2
# 1000-1499    2
# 1500+        2
# Name: categoria, dtype: int64

# %%
# %%writefile /tmp/data.csv
# carros
# spark
# hummer
# ram
# i10
# fiesta
# festiva
# tahoe
# onix
# aveo
# blazer
# captiva
# spark
# hummer
# ram
# i10
# fiesta
# festiva
# tahoe
# onix
# aveo
# blazer
# captiva
# ram
# i10
# fiesta
# festiva
# tahoe
# onix
# spark
# hummer
# ram
# i10
# fiesta
# festiva
# tahoe
# onix
# aveo
# blazer
# captiva
# ram
# i10
# Out:
# Overwriting /tmp/data.csv

# %%
mapping = {
    'spark':'urbanos',
    'hummer':'truks',
    'ram':'truks',
    'i10':'urbanos',
    'fiesta':'urbanos',
    'festiva':'urbanos',
    'tahoe':'camionetas',
    'onix':'urbanos',
    'aveo':'urbanos',
    'blazer':'camionetas',
    'captiva':'camionetas'
}

# %%
df = pd.read_csv('/tmp/data.csv')

# %%
df['categoria'] = df.carros.replace(mapping)
df
# Out:
#      carros   categoria
# 0     spark     urbanos
# 1    hummer       truks
# 2       ram       truks
# 3       i10     urbanos
# 4    fiesta     urbanos
# 5   festiva     urbanos
# 6     tahoe  camionetas
# 7      onix     urbanos
# 8      aveo     urbanos
# 9    blazer  camionetas
# 10  captiva  camionetas
# 11    spark     urbanos
# 12   hummer       truks
# 13      ram       truks
# 14      i10     urbanos
# 15   fiesta     urbanos
# 16  festiva     urbanos
# 17    tahoe  camionetas
# 18     onix     urbanos
# 19     aveo     urbanos
# 20   blazer  camionetas
# 21  captiva  camionetas
# 22      ram       truks
# 23      i10     urbanos
# 24   fiesta     urbanos
# 25  festiva     urbanos
# 26    tahoe  camionetas
# 27     onix     urbanos
# 28    spark     urbanos
# 29   hummer       truks
# 30      ram       truks
# 31      i10     urbanos
# 32   fiesta     urbanos
# 33  festiva     urbanos
# 34    tahoe  camionetas
# 35     onix     urbanos
# 36     aveo     urbanos
# 37   blazer  camionetas
# 38  captiva  camionetas
# 39      ram       truks
# 40      i10     urbanos

# %%
df.categoria.value_counts()
# Out:
# urbanos       23
# camionetas    10
# truks          8
# Name: categoria, dtype: int64

# %%
# %%writefile /tmp/data.csv
# telefono
# +057-634-345-789
# 57-456-234-456
#  57.654.890.654
# 213
# (057)-345-345-345
# 57 322 455 322
# Out:
# Overwriting /tmp/data.csv

# %%
df = pd.read_csv('/tmp/data.csv')
display(
    df,
    df.dtypes
)
# Out:
#             telefono
# 0   +057-634-345-789
# 1     57-456-234-456
# 2     57.654.890.654
# 3                213
# 4  (057)-345-345-345
# 5     57 322 455 322
# telefono    object
# dtype: object

# %%
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#             telefono
# 3                213
# 1     57-456-234-456
# 5     57 322 455 322
# 2     57.654.890.654
# 0   +057-634-345-789
# 4  (057)-345-345-345

# %%
df.telefono = df.telefono.str.replace('+', '')
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#             telefono
# 3                213
# 1     57-456-234-456
# 5     57 322 455 322
# 0    057-634-345-789
# 2     57.654.890.654
# 4  (057)-345-345-345

# %%
df.telefono = df.telefono.str.replace('[()]','')
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#           telefono
# 3              213
# 1   57-456-234-456
# 5   57 322 455 322
# 0  057-634-345-789
# 2   57.654.890.654
# 4  057-345-345-345

# %%
df.telefono = df.telefono.map(lambda x: '0' + x if re.search(r"^57[\s\.\-]", x) else x)
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#           telefono
# 3              213
# 0  057-634-345-789
# 1  057-456-234-456
# 2   57.654.890.654
# 4  057-345-345-345
# 5  057 322 455 322

# %%
df.telefono = df.telefono.map(lambda x: '0' + x[1:] if re.search(r"^\s57[\s\.\-]", x) else x)
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#           telefono
# 3              213
# 0  057-634-345-789
# 1  057-456-234-456
# 2  057.654.890.654
# 4  057-345-345-345
# 5  057 322 455 322

# %%
df.telefono = df.telefono.str.replace(' ', '-')
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#           telefono
# 3              213
# 0  057-634-345-789
# 1  057-456-234-456
# 2  057.654.890.654
# 4  057-345-345-345
# 5  057-322-455-322

# %%
df.telefono = df.telefono.str.replace('.', '-')
df.sort_values('telefono', key=lambda series : [len(x) for x in series])
# Out:
#           telefono
# 3              213
# 0  057-634-345-789
# 1  057-456-234-456
# 2  057-654-890-654
# 4  057-345-345-345
# 5  057-322-455-322

# %%
df.telefono = df.telefono.map(lambda x: np.nan if len(x) < 12 else x)
df
# Out:
#           telefono
# 0  057-634-345-789
# 1  057-456-234-456
# 2  057-654-890-654
# 3              NaN
# 4  057-345-345-345
# 5  057-322-455-322

# %%
from fuzzywuzzy import fuzz, process

# %%
display(
    fuzz.WRatio('hola mundo', 'hola mundo'),
    fuzz.WRatio('hola mundo', 'Hola mundo'),
    fuzz.WRatio('hola mundo', 'hola Mundo'),
    fuzz.WRatio('hola mundo', 'hola mundo!')
)
# Out:
# 100
# 100
# 100
# 100

# %%
display(
    fuzz.WRatio('hola mundo', 'hola mundo'),
    fuzz.WRatio('hola mundo', 'Hola'),
    fuzz.WRatio('hola mundo', 'Mundo'),
    fuzz.WRatio('hola mundo', 'hola mundo!'),
    fuzz.WRatio('hola mundo', 'hola muuundo'),
    fuzz.WRatio('hola mundo', 'hoooola mundo')
)
# Out:
# 100
# 90
# 90
# 100
# 91
# 87

# %%
cadena = 'hola mundo'
arreglo = pd.Series(
    [
        'hola',
        'hola mundo',
        'mmmoo',
        'hola munnndooo'
    ]
)

process.extract(cadena, arreglo)
# Out:
# [('hola mundo', 100, 1),
#  ('hola', 90, 0),
#  ('hola munnndooo', 83, 3),
#  ('mmmoo', 36, 2)]

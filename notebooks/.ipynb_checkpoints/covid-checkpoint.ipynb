# %% [markdown]
# # Ejercicio covid-19
#
# importamos las librerías

# %%
import pandas as pd
import numpy as np

import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# Cargamos el dataset

# %%
covid_df = pd.read_csv('Casos_positivos_de_COVID-19_en_Colombia.csv')
display(
    covid_df.head(),
    covid_df.shape
)
# Out:
#    fecha reporte web  ID de caso Fecha de notificación  \
# 0   6/3/2020 0:00:00           1      2/3/2020 0:00:00
# 1   9/3/2020 0:00:00           2      6/3/2020 0:00:00
# 2   9/3/2020 0:00:00           3      7/3/2020 0:00:00
# 3  11/3/2020 0:00:00           4      9/3/2020 0:00:00
# 4  11/3/2020 0:00:00           5      9/3/2020 0:00:00
#
#    Código DIVIPOLA departamento Nombre departamento  \
# 0                            11              BOGOTA
# 1                            76               VALLE
# 2                             5           ANTIOQUIA
# 3                             5           ANTIOQUIA
# 4                             5           ANTIOQUIA
#
#    Código DIVIPOLA municipio Nombre municipio  Edad  Unidad de medida de edad  \
# 0                      11001           BOGOTA    19                         1
# 1                      76111             BUGA    34                         1
# 2                       5001         MEDELLIN    50                         1
# 3                       5001         MEDELLIN    55                         1
# 4                       5001         MEDELLIN    25                         1
#
#   Sexo  ... Código ISO del país Nombre del país  Recuperado  \
# 0    F  ...               380.0          ITALIA  Recuperado
# 1    M  ...               724.0          ESPAÑA  Recuperado
# 2    F  ...               724.0          ESPAÑA  Recuperado
# 3    M  ...                 NaN             NaN  Recuperado
# 4    M  ...                 NaN             NaN  Recuperado
#
#    Fecha de inicio de síntomas Fecha de muerte Fecha de diagnóstico  \
# 0            27/2/2020 0:00:00             NaN     6/3/2020 0:00:00
# 1             4/3/2020 0:00:00             NaN     9/3/2020 0:00:00
# 2            29/2/2020 0:00:00             NaN     9/3/2020 0:00:00
# 3             6/3/2020 0:00:00             NaN    11/3/2020 0:00:00
# 4             8/3/2020 0:00:00             NaN    11/3/2020 0:00:00
#
#   Fecha de recuperación Tipo de recuperación Pertenencia étnica  \
# 0     13/3/2020 0:00:00                  PCR                6.0
# 1     19/3/2020 0:00:00                  PCR                5.0
# 2     15/3/2020 0:00:00                  PCR                6.0
# 3     26/3/2020 0:00:00                  PCR                6.0
# 4     23/3/2020 0:00:00                  PCR                6.0
#
#   Nombre del grupo étnico
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 23 columns]
# (4852323, 23)

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852323 entries, 0 to 4852322
# Data columns (total 23 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   fecha reporte web             object
#  1   ID de caso                    int64
#  2   Fecha de notificación         object
#  3   Código DIVIPOLA departamento  int64
#  4   Nombre departamento           object
#  5   Código DIVIPOLA municipio     int64
#  6   Nombre municipio              object
#  7   Edad                          int64
#  8   Unidad de medida de edad      int64
#  9   Sexo                          object
#  10  Tipo de contagio              object
#  11  Ubicación del caso            object
#  12  Estado                        object
#  13  Código ISO del país           float64
#  14  Nombre del país               object
#  15  Recuperado                    object
#  16  Fecha de inicio de síntomas   object
#  17  Fecha de muerte               object
#  18  Fecha de diagnóstico          object
#  19  Fecha de recuperación         object
#  20  Tipo de recuperación          object
#  21  Pertenencia étnica            float64
#  22  Nombre del grupo étnico       object
# dtypes: float64(2), int64(5), object(16)
# memory usage: 851.5+ MB

# %%
sorted(covid_df.columns)
# Out:
# ['Código DIVIPOLA departamento',
#  'Código DIVIPOLA municipio',
#  'Código ISO del país',
#  'Edad',
#  'Estado',
#  'Fecha de diagnóstico',
#  'Fecha de inicio de síntomas',
#  'Fecha de muerte',
#  'Fecha de notificación',
#  'Fecha de recuperación',
#  'ID de caso',
#  'Nombre del grupo étnico',
#  'Nombre del país',
#  'Nombre departamento',
#  'Nombre municipio',
#  'Pertenencia étnica',
#  'Recuperado',
#  'Sexo',
#  'Tipo de contagio',
#  'Tipo de recuperación',
#  'Ubicación del caso',
#  'Unidad de medida de edad',
#  'fecha reporte web']

# %%
covid_df['Edad'].describe()
# Out:
# count    4.852323e+06
# mean     3.954936e+01
# std      1.790326e+01
# min      1.000000e+00
# 25%      2.700000e+01
# 50%      3.700000e+01
# 75%      5.200000e+01
# max      1.140000e+02
# Name: Edad, dtype: float64

# %%
covid_df.loc[(covid_df['Sexo'] == 'f'),['Sexo']] = 'F'
covid_df.loc[(covid_df['Sexo'] == 'm'),['Sexo']] = 'M'
covid_df.loc[(covid_df['Estado'] == 'leve'),['Estado']] = 'Leve'
covid_df.loc[(covid_df['Estado'] == 'LEVE'),['Estado']] = 'Leve'

# %%
df = covid_df.groupby(['Sexo', 'Estado'])['ID de caso'].count()
df
# Out:
# Sexo  Estado
# F     Fallecido      47744
#       Grave           1088
#       Leve         2481446
#       Moderado        8651
# M     Fallecido      75209
#       Grave           1497
#       Leve         2211047
#       Moderado        8957
# Name: ID de caso, dtype: int64

# %%
df = covid_df.groupby(['Sexo', 'Estado'])['Edad'].mean()
df
# Out:
# Sexo  Estado
# F     Fallecido    68.793922
#       Grave        52.006434
#       Leve         39.017059
#       Moderado     48.582360
# M     Fallecido    66.764762
#       Grave        50.816299
#       Leve         38.297667
#       Moderado     49.017863
# Name: Edad, dtype: float64

# %%
df = covid_df.groupby(['Sexo', 'Estado'])['Edad'].max()
df
# Out:
# Sexo  Estado
# F     Fallecido    108
#       Grave         98
#       Leve         114
#       Moderado     111
# M     Fallecido    110
#       Grave         94
#       Leve         114
#       Moderado      99
# Name: Edad, dtype: int64

# %%
df = covid_df.groupby(['Sexo', 'Estado'])['Edad'].min()
df
# Out:
# Sexo  Estado
# F     Fallecido    1
#       Grave        1
#       Leve         1
#       Moderado     1
# M     Fallecido    1
#       Grave        1
#       Leve         1
#       Moderado     1
# Name: Edad, dtype: int64

# %% [markdown]
# filtramos los casos fallecidos

# %%
fallecidos_df = covid_df[(covid_df['Estado']=='Fallecido')]

# %%
cantidad_fallecidos = len(fallecidos_df)
cantidad_fallecidos
# Out:
# 122953

# %% [markdown]
# Filtramos por los fallecidos que están por debajo de la edad promedio

# %%
fallecidos_promedio_df = fallecidos_df.groupby('Estado')['Edad'].transform('mean')

# %%
display(
    fallecidos_promedio_df.head(),
    len(fallecidos_promedio_df)
)
# Out:
# 151    67.552707
# 152    67.552707
# 156    67.552707
# 187    67.552707
# 196    67.552707
# Name: Edad, dtype: float64
# 122953

# %%
fallecidos_df['mean'] = fallecidos_promedio_df

# %%
display(
    fallecidos_df[['ID de caso', 'Edad', 'mean']].head(),
    len(fallecidos_df)
)
# Out:
#      ID de caso  Edad       mean
# 151         152    65  67.552707
# 152         153    53  67.552707
# 156         157    88  67.552707
# 187         188    70  67.552707
# 196         197    58  67.552707
# 122953

# %%
df = fallecidos_df[fallecidos_df['Edad'] < fallecidos_df['mean']]

# %%
display(
    df[['ID de caso', 'Edad', 'mean']].head(),
    len(df)
)
# Out:
#      ID de caso  Edad       mean
# 151         152    65  67.552707
# 152         153    53  67.552707
# 196         197    58  67.552707
# 231         232    59  67.552707
# 260         261    61  67.552707
# 57172

# %%
menores_fallecidos_df = fallecidos_df[fallecidos_df['Edad'] < 18]

# %%
display(
    menores_fallecidos_df[['ID de caso', 'Edad']].head(),
    len(menores_fallecidos_df)
)
# Out:
#        ID de caso  Edad
# 1573         1574     3
# 3963         3964     1
# 6643         6684     1
# 9492         9533     7
# 10626       10667     3
# 218

# %% [markdown]
# conteo de menores de edad fallecidos por departamento

# %%
df = menores_fallecidos_df.groupby('Nombre departamento')['ID de caso'].count()
display(df.to_frame())
# Out:
#                      ID de caso
# Nombre departamento
# AMAZONAS                      2
# ANTIOQUIA                    16
# ARAUCA                        1
# ATLANTICO                    14
# BARRANQUILLA                  7
# BOGOTA                       34
# BOLIVAR                       6
# BOYACA                        6
# CALDAS                        2
# CAQUETA                       3
# CARTAGENA                     9
# CASANARE                      2
# CAUCA                         4
# CESAR                        11
# CORDOBA                      10
# CUNDINAMARCA                 11
# GUAJIRA                       4
# HUILA                         7
# MAGDALENA                     3
# META                          3
# NARIÑO                        7
# NORTE SANTANDER               9
# PUTUMAYO                      1
# QUINDIO                       1
# RISARALDA                     2
# SAN ANDRES                    1
# SANTANDER                    11
# STA MARTA D.E.                5
# SUCRE                         6
# TOLIMA                        4
# VALLE                        14
# VAUPES                        1
# VICHADA                       1

# %%
df_por_dep = df.to_frame()
df_por_dep.columns = ['Casos']
df_por_dep.head()
# Out:
#                      Casos
# Nombre departamento
# AMAZONAS                 2
# ANTIOQUIA               16
# ARAUCA                   1
# ATLANTICO               14
# BARRANQUILLA             7

# %%
df_por_dep = df_por_dep.sort_values(by='Casos', ascending=False)

# %%
df_top_fall = df_por_dep.head(10)

# %%
df_top_fall
# Out:
#                      Casos
# Nombre departamento
# BOGOTA                  34
# ANTIOQUIA               16
# VALLE                   14
# ATLANTICO               14
# CESAR                   11
# CUNDINAMARCA            11
# SANTANDER               11
# CORDOBA                 10
# NORTE SANTANDER          9
# CARTAGENA                9

# %%
covid_df
# Out:
#          fecha reporte web  ID de caso Fecha de notificación  \
# 0         6/3/2020 0:00:00           1      2/3/2020 0:00:00
# 1         9/3/2020 0:00:00           2      6/3/2020 0:00:00
# 2         9/3/2020 0:00:00           3      7/3/2020 0:00:00
# 3        11/3/2020 0:00:00           4      9/3/2020 0:00:00
# 4        11/3/2020 0:00:00           5      9/3/2020 0:00:00
# ...                    ...         ...                   ...
# 4852318  11/8/2021 0:00:00     4852359     29/3/2021 0:00:00
# 4852319  11/8/2021 0:00:00     4852360     29/3/2021 0:00:00
# 4852320  11/8/2021 0:00:00     4852361     29/3/2021 0:00:00
# 4852321  11/8/2021 0:00:00     4852362     29/3/2021 0:00:00
# 4852322  11/8/2021 0:00:00     4852363     29/3/2021 0:00:00
#
#          Código DIVIPOLA departamento Nombre departamento  \
# 0                                  11              BOGOTA
# 1                                  76               VALLE
# 2                                   5           ANTIOQUIA
# 3                                   5           ANTIOQUIA
# 4                                   5           ANTIOQUIA
# ...                               ...                 ...
# 4852318                         47001      STA MARTA D.E.
# 4852319                         47001      STA MARTA D.E.
# 4852320                         47001      STA MARTA D.E.
# 4852321                         47001      STA MARTA D.E.
# 4852322                         47001      STA MARTA D.E.
#
#          Código DIVIPOLA municipio Nombre municipio  Edad  \
# 0                            11001           BOGOTA    19
# 1                            76111             BUGA    34
# 2                             5001         MEDELLIN    50
# 3                             5001         MEDELLIN    55
# 4                             5001         MEDELLIN    25
# ...                            ...              ...   ...
# 4852318                      47001      SANTA MARTA    58
# 4852319                      47001      SANTA MARTA    53
# 4852320                      47001      SANTA MARTA    44
# 4852321                      47001      SANTA MARTA    42
# 4852322                      47001      SANTA MARTA    37
#
#          Unidad de medida de edad Sexo  ... Código ISO del país  \
# 0                               1    F  ...               380.0
# 1                               1    M  ...               724.0
# 2                               1    F  ...               724.0
# 3                               1    M  ...                 NaN
# 4                               1    M  ...                 NaN
# ...                           ...  ...  ...                 ...
# 4852318                         1    M  ...                 NaN
# 4852319                         1    F  ...                 NaN
# 4852320                         1    F  ...                 NaN
# 4852321                         1    F  ...                 NaN
# 4852322                         1    M  ...                 NaN
#
#         Nombre del país  Recuperado  Fecha de inicio de síntomas  \
# 0                ITALIA  Recuperado            27/2/2020 0:00:00
# 1                ESPAÑA  Recuperado             4/3/2020 0:00:00
# 2                ESPAÑA  Recuperado            29/2/2020 0:00:00
# 3                   NaN  Recuperado             6/3/2020 0:00:00
# 4                   NaN  Recuperado             8/3/2020 0:00:00
# ...                 ...         ...                          ...
# 4852318             NaN      Activo            25/3/2021 0:00:00
# 4852319             NaN      Activo            25/3/2021 0:00:00
# 4852320             NaN      Activo            25/3/2021 0:00:00
# 4852321             NaN      Activo            25/3/2021 0:00:00
# 4852322             NaN      Activo            25/3/2021 0:00:00
#
#         Fecha de muerte Fecha de diagnóstico Fecha de recuperación  \
# 0                   NaN     6/3/2020 0:00:00     13/3/2020 0:00:00
# 1                   NaN     9/3/2020 0:00:00     19/3/2020 0:00:00
# 2                   NaN     9/3/2020 0:00:00     15/3/2020 0:00:00
# 3                   NaN    11/3/2020 0:00:00     26/3/2020 0:00:00
# 4                   NaN    11/3/2020 0:00:00     23/3/2020 0:00:00
# ...                 ...                  ...                   ...
# 4852318             NaN     9/4/2021 0:00:00                   NaN
# 4852319             NaN     9/4/2021 0:00:00                   NaN
# 4852320             NaN     9/4/2021 0:00:00                   NaN
# 4852321             NaN     9/4/2021 0:00:00                   NaN
# 4852322             NaN     9/4/2021 0:00:00                   NaN
#
#         Tipo de recuperación Pertenencia étnica Nombre del grupo étnico
# 0                        PCR                6.0                     NaN
# 1                        PCR                5.0                     NaN
# 2                        PCR                6.0                     NaN
# 3                        PCR                6.0                     NaN
# 4                        PCR                6.0                     NaN
# ...                      ...                ...                     ...
# 4852318                  NaN                NaN                     NaN
# 4852319                  NaN                NaN                     NaN
# 4852320                  NaN                NaN                     NaN
# 4852321                  NaN                NaN                     NaN
# 4852322                  NaN                NaN                     NaN
#
# [4852323 rows x 23 columns]

# %% [markdown]
# Vamos a agregar la clasificación de casos __internos__ y __foraneos__ al dataframe original
#
# - agregar dos columnas aplicando una funcion que definimos usando __lambdas__ y aplicamos usando __map__

# %%
covid_df['internos'] = covid_df['Nombre del país'].map(
    lambda x: 1 if pd.isna(x) else 0
)

# %%
covid_df[['ID de caso','Nombre del país','internos']].head()
# Out:
#    ID de caso Nombre del país  internos
# 0           1          ITALIA         0
# 1           2          ESPAÑA         0
# 2           3          ESPAÑA         0
# 3           4             NaN         1
# 4           5             NaN         1

# %%
covid_df['foraneos'] = covid_df['Nombre del país'].map(
    lambda x: 1 if not pd.isna(x) else 0
)

# %%
covid_df[['ID de caso','Nombre del país','internos','foraneos']].head()
# Out:
#    ID de caso Nombre del país  internos  foraneos
# 0           1          ITALIA         0         1
# 1           2          ESPAÑA         0         1
# 2           3          ESPAÑA         0         1
# 3           4             NaN         1         0
# 4           5             NaN         1         0

# %%
foraneos = covid_df.foraneos.sum() / covid_df.foraneos.count() * 100
internos = covid_df.internos.sum() / covid_df.internos.count() * 100

display(
    "Casos foraneos {:4.2f} %".format(foraneos),
    "Casos internos {:4.2f} %".format(internos)
)
# Out:
# 'Casos foraneos 0.06'
# 'Casos internos 99.94'
